# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
egfp=np.array(pd.read_excel('data-siRNA/2017_06_02_seq6_Huh7_controll_#molecules.xlsx', sheet_name="#GFP_corrected")).T
egfp.shape
# Out:
# (443, 150)

# %%
time = egfp[0]
data = egfp[11]
plt.figure()
plt.plot(time,data)
